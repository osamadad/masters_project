# %% [markdown]
# <a href="https://colab.research.google.com/github/osamadad/masters_project/blob/main/yolo12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# !pip install roboflow
# !pip install grad-cam
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.5/983.5 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="pegL48guzlGkiTlbCaRc")
project = rf.workspace("osos-workplace").project("object-detection-in-av-rs8lg")
version = project.version(3)
dataset = version.download("yolov12")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to object-detection-in-AV-3 in yolov12:: 100%|██████████| 39002/39002 [00:05<00:00, 7549.43it/s]

# %%
# !pip install -U ultralytics wandb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 109.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.19.9
#     Uninstalling wandb-0.19.9:
#       Successfully uninstalled wandb-0.19.9
# ...

# %%
import wandb

# Initialize your Weights & Biases environment
wandb.login(key="2c1925a1cbe1037df66a890498860e36070b426d")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: osamadad768 (osamadad768-taibah-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !yolo settings wandb=True
# Out:
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/content/datasets",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": true,
#   "vscode_msg": true
# }
# 💡 Learn more about Ultralytics Settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings

# %%
wandb.init(project="yolo12", job_type="training")
# Out:
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250424_002834-5sc8vsar</code>
# Syncing run <strong><a href='https://wandb.ai/osamadad768-taibah-university/yolo12/runs/5sc8vsar' target="_blank">electric-feather-1</a></strong> to <a href='https://wandb.ai/osamadad768-taibah-university/yolo12' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/osamadad768-taibah-university/yolo12' target="_blank">https://wandb.ai/osamadad768-taibah-university/yolo12</a>
#  View run at <a href='https://wandb.ai/osamadad768-taibah-university/yolo12/runs/5sc8vsar' target="_blank">https://wandb.ai/osamadad768-taibah-university/yolo12/runs/5sc8vsar</a>
# ...

# %%
# !yolo detect train data=/content/object-detection-in-AV-3/data.yaml model=yolo12m.pt epochs=120 imgsz=640 batch=42 amp=True patience=50 conf=0.4 optimizer=SGD
# Out:
# Ultralytics 8.3.115 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
model = YOLO("/content/runs/detect/train2/weights/best.pt")  # load a custom model

metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics 8.3.115 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv12m summary (fused): 169 layers, 20,109,538 parameters, 0 gradients, 67.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1814.9±599.5 MB/s, size: 47.9 KB)
# val: Scanning /content/object-detection-in-AV-3/valid/labels.cache... 3899 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3899/3899 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 244/244 [00:32<00:00,  7.50it/s]
#                    all       3899      12415      0.947      0.923      0.962      0.813
#                    Car       1395       5892      0.951       0.96      0.985      0.875
#                Cyclist       2611       4742       0.95      0.914      0.965      0.851
#             Pedestrian        351        805      0.942      0.769      0.881       0.57
# ...

# %%
import shutil
shutil.make_archive('val2', 'zip', '/content/runs/detect/val2')
# Out:
# '/content/val2.zip'
